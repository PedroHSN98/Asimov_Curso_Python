# %%
produtos = {
    'banana': 3.60,
    'leite': 4.90,
    'carne': 15.90,
    'pão': 9.00,
}

# %%
produtos.clear()

# %%
produtos
# Out:
# {}

# %%
produtos = {
    'banana': 3.60,
    'leite': 4.90,
    'carne': 15.90,
    'pão': 9.00,
}

# %%
produtos.get('banana')
# Out:
# 3.6

# %%
produtos.get('pão')
# Out:
# 9.0

# %%
resultado = produtos.get('banana')

# %%
resultado
# Out:
# 3.6

# %%
resultado = produtos.get('arroz')

# %%
print(resultado)
# Out:
# None

# %%
produtos
# Out:
# {'banana': 3.6, 'leite': 4.9, 'carne': 15.9, 'pão': 9.0}

# %%
produtos.setdefault('arroz', 100)
# Out:
# 100

# %%
produtos
# Out:
# {'banana': 3.6, 'leite': 4.9, 'carne': 15.9, 'pão': 9.0, 'arroz': 100}

# %%
for produto in produtos.keys():
    print(produto)
# Out:
# banana
# leite
# carne
# pão
# arroz

# %%
for valor in produtos.values():
    print(valor)
# Out:
# 3.6
# 4.9
# 15.9
# 9.0
# 100

# %%
for par in produtos.items():
    print(par)
# Out:
# ('banana', 3.6)
# ('leite', 4.9)
# ('carne', 15.9)
# ('pão', 9.0)
# ('arroz', 100)

# %%
for k, v in produtos.items():
    print(f'{k} -> {v}')
# Out:
# banana -> 3.6
# leite -> 4.9
# carne -> 15.9
# pão -> 9.0
# arroz -> 100

# %%
produtos = {
    'banana': 3.60,
    'leite': 4.90,
    'carne': 15.90,
    'pão': 9.00,
}


novos_produtos = {
    'massa': 5.70,
    'banana': 4.40,
}

# %%
produtos.update(novos_produtos)

# %%
produtos
# Out:
# {'banana': 4.4, 'leite': 4.9, 'carne': 15.9, 'pão': 9.0, 'massa': 5.7}

# %%
produtos = {
    'banana': 3.60,
    'leite': 4.90,
    'carne': 15.90,
    'pão': 9.00,
}

# %%
produtos_copia = produtos.copy()

# %%
produtos_copia['morango'] = 3.30

# %%
produtos
# Out:
# {'banana': 3.6, 'leite': 4.9, 'carne': 15.9, 'pão': 9.0}

# %%
produtos_copia
# Out:
# {'banana': 3.6, 'leite': 4.9, 'carne': 15.9, 'pão': 9.0, 'morango': 3.3}
