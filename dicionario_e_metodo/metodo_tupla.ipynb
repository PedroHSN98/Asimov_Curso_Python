# %%
tup = (0, 0, 0, 1, 0, 1, 0 )

# %%
tup.index(1)
# Out:
# 3

# %%
tup.count(0)
# Out:
# 5

# %%
l1 = [0, 0, 0, 1, 1, 0, 0]

# %%
l2 = l1.copy

# %%
l1
# Out:
# [0, 0, 0, 1, 1, 0, 0]

# %%
l2
# Out:
# <function list.copy()>

# %%
l1.clear()

# %%
l2
# Out:
# <function list.copy()>

# %%
l1
# Out:
# []

# %%
for n in range(5):
    l1.append(n * 2)

# %%
l1
# Out:
# [0, 2, 4, 6, 8]

# %%
l1.append('hello')

# %%
l1
# Out:
# [0, 2, 4, 6, 8, 'hello']

# %%
valores = [10, 20, 50, -1]

# %%
valores_positivo = []

# %%
for valor in valores:
    if valor > 0:
        valores_positivo.append(valor)

# %%
valores_positivo
# Out:
# [10, 20, 50]

# %%
numeros = [1, 2, 3]

# %%
numeros.append([4, 5, 6])

# %%
numeros
# Out:
# [1, 2, 3, [4, 5, 6]]

# %%
numeros = [1, 2, 3]

# %%
numeros.extend([4, 5, 6])

# %%
numeros
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
numeros = [1, 2, 3]

# %%
novos_numeros = numeros + [4, 5, 6]

# %%
novos_numeros
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
vogais = ['a', 'i', 'o', 'u']

# %%
vogais.insert(1, 'e')

# %%
vogais
# Out:
# ['a', 'e', 'i', 'o', 'u']

# %%
vogais.insert(-1, 'e')

# %%
vogais
# Out:
# ['a', 'e', 'i', 'o', 'e', 'u']

# %%
valores
# Out:
# [10, 20, 50, -1]

# %%
valor_removido = valores.pop()

# %%
valor_removido
# Out:
# -1

# %%
valores
# Out:
# [10, 20, 50]

# %%
valor_removido = valores.pop(0)

# %%
valores
# Out:
# [20, 50]
