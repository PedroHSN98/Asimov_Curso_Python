# %%
produtos = {
    'banana': 3.60,
    'leite': 4.90,
    'carne': 15.90,
    'pão': 9.00,
}

# %%
produtos
# Out:
# {'banana': 3.6, 'leite': 4.9, 'carne': 15.9, 'pão': 9.0}

# %%
produtos.clear()

# %%
produtos
# Out:
# {}

# %%
dir(produtos)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
help(produtos.clear)
# Out:
# Help on built-in function clear:
#
# clear() method of builtins.dict instance
#     Remove all items from the dict.
