# %%
capitais = {
    'Brasil': 'Brasília',
    'França': 'Paris',
    'Japão': 'Tóquio',
}

# %%
print(capitais)
capitais['Brasil']
# Out:
# {'Brasil': 'Brasília', 'França': 'Paris', 'Japão': 'Tóquio'}
# 'Brasília'

# %%
capitais['França']
# Out:
# 'Paris'

# %%
capitais['Japão']
capitais['Inglaterra'] = 'Londres'

# %%
capitais
# Out:
# {'Brasil': 'Brasília',
#  'França': 'Paris',
#  'Japão': 'Tóquio',
#  'Inglaterra': 'Londres'}

# %%
del capitais['Inglaterra']

# %%
capitais
# Out:
# {'Brasil': 'Brasília', 'França': 'Paris', 'Japão': 'Tóquio'}

# %%
'Brasil' in capitais
# Out:
# True
