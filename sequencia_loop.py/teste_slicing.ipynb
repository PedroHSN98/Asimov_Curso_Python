# %%
alunos = ['Lucas', 'Geovanne', 'Fabio', 'Maria', 'Junior']

# %%
list(alunos)
# Out:
# ['Lucas', 'Geovanne', 'Fabio', 'Maria', 'Junior']

# %%
alunos[1:4]
# Out:
# ['Geovanne', 'Fabio', 'Maria']

# %%
len(alunos)
# Out:
# 5

# %%
alunos[0::2]
# Out:
# ['Lucas', 'Fabio', 'Junior']

# %%
alunos[0::3]
# Out:
# ['Lucas', 'Maria']

# %%
alunos
# Out:
# ['Lucas', 'Geovanne', 'Fabio', 'Maria', 'Junior']

# %%
alunos[1]
# Out:
# 'Geovanne'

# %%
nome = 'Fernando'

# %%
nome[2]
# Out:
# 'r'

# %%
nome[0::2]
# Out:
# 'Frad'
