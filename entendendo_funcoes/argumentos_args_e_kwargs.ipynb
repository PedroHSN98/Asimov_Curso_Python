# %% [markdown]
# ### Argumentos arbitrários com Args e Kwargs

# %%
def exibe_argumentos(a, b, c, *args, **kwargs):
    #args = argumentos qualquer, ou seja, uma quantidade indefinida de argumentos
    # kwargs = argumentos nomeados, ou seja, uma quantidade indefinida de argumentos nomeados
    print(a, b, c)
    print(f'Argumentos passados sem palavras-chave: {args}')
    print(f'Argumentos passados com palavras-chave: {kwargs}')

# %%
valores = [1, 2, 4]
dic = {
    'nome' : 'Pedro',
    'idade' : 30,
    'senha' : None
    'filtro' : None
}

dic['senha'] = pegar_senha()
dic['filtro'] = ...

exibe_argumentos(*valores, **dic)
#exibe_argumentos(1, 2, 3, 5, 50, 30, x=5, y=10)
# Out:
# 1 2 4
# Argumentos passados sem palavras-chave: ()
# Argumentos passados com palavras-chave: {'nome': 'Pedro', 'idade': 30}
# O Kernel deu pane ao executar o código na célula atual ou em uma célula anterior.
#
# Analise o código nas células para identificar uma possível causa da pane.
#
# Clique <a href='https://aka.ms/vscodeJupyterKernelCrash'>aqui</a> para obter mais informações.
#
# Consulte Jupyter <a href='command:jupyter.viewOutput'>log</a> para obter mais detalhes.
