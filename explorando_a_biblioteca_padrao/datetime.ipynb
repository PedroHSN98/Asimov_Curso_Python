# %% [markdown]
# ### Trabalhar com data e hora

# %%
import datetime

data = datetime.date(2022, 1, 5)

# %%
data
# Out:
# datetime.date(2022, 1, 5)

# %%
hora = datetime.time(18, 6, 35)

# %%
hora
# Out:
# datetime.time(18, 6, 35)

# %%
datetime.datetime(2022, 1, 5, 18, 6, )
#(ano, mes, dia, hora, minuto, segundo)
# Out:
# datetime.datetime(2022, 1, 5, 18, 6)

# %%
instante = datetime.datetime(2022, 1, 5, 18, 6,36)

# %%
instante.strftime('Dia %d/%m/%Y, as %H horas e %m Minutos')
# Out:
# 'Dia 05/01/2022, as 18 horas e 01 Minutos'

# %%
instante.strftime('[ %Y-%m-%d --- %H:%M:%S]')
# Out:
# '[ 2022-01-05 --- 18:06:36]'
