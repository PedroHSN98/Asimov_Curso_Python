# %% [markdown]
# ### Interação com arquivos e sistemas operacional

# %%
import os 

os.getcwd()
# Out:
# 'c:\\Users\\8761221\\Documents\\Asimov\\Python_Intermediario\\explorando_a_biblioteca_padrao'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'notas.txt', 'os.ipynb']

# %%
os.environ['PATH']
# Out:
# 'c:\\Users\\8761221\\AppData\\Local\\anaconda3;C:\\Users\\8761221\\AppData\\Local\\anaconda3;C:\\Users\\8761221\\AppData\\Local\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\8761221\\AppData\\Local\\anaconda3\\Library\\usr\\bin;C:\\Users\\8761221\\AppData\\Local\\anaconda3\\Library\\bin;C:\\Users\\8761221\\AppData\\Local\\anaconda3\\Scripts;C:\\Users\\8761221\\AppData\\Local\\anaconda3\\bin;C:\\Users\\8761221\\AppData\\Local\\anaconda3\\condabin;C:\\Users\\8761221\\AppData\\Local\\Programs\\Microsoft VS Code;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0;C:\\WINDOWS\\System32\\OpenSSH;c:\\Program Files (x86)\\Microsoft SQL Server\\110\\Tools\\Binn;c:\\Program Files\\Microsoft SQL Server\\110\\Tools\\Binn;c:\\Program Files\\Microsoft SQL Server\\110\\DTS\\Binn;C:\\Program Files\\dotnet;C:\\Program Files\\nodejs;C:\\Program Files\\Git\\cmd;C:\\Program Files\\Docker\\Docker\\resources\\bin;C:\\Users\\8761221\\AppData\\Local\\anaconda3;C:\\Users\\8761221\\AppData\\Local\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\8761221\\AppData\\Local\\anaconda3\\Library\\usr\\bin;C:\\Users\\8761221\\AppData\\Local\\anaconda3\\Library\\bin;C:\\Users\\8761221\\AppData\\Local\\anaconda3\\Scripts;c:\\Users\\8761221\\AppData\\Local\\Programs\\Trae\\bin;C:\\Users\\8761221\\AppData\\Local\\Programs\\Python\\Python313\\Scripts;C:\\Users\\8761221\\AppData\\Local\\Programs\\Python\\Python313;C:\\Users\\8761221\\AppData\\Local\\Programs\\Python\\Launcher;C:\\Users\\8761221\\AppData\\Local\\Programs\\Python\\Python312\\Scripts;C:\\Users\\8761221\\AppData\\Local\\Programs\\Python\\Python312;C:\\Users\\8761221\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\8761221\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Users\\8761221\\AppData\\Local\\GitHubDesktop\\bin;C:\\Users\\8761221\\AppData\\Roaming\\npm'

# %%
from pathlib import Path
p = Path('.')

# %%
p
# Out:
# WindowsPath('.')

# %%
p.absolute()
# Out:
# WindowsPath('c:/Users/8761221/Documents/Asimov/Python_Intermediario/explorando_a_biblioteca_padrao')

# %%
list(p.iterdir())
# Out:
# [WindowsPath('.ipynb_checkpoints'),
#  WindowsPath('notas.txt'),
#  WindowsPath('os.ipynb')]

# %%
nome_arquivo = 'notas.txt'

with open(nome_arquivo, 'w') as arquivo_texto:
    arquivo_texto.write('Estou aprendendo Ptyhon')

# %%
pasta = Path('.').absolute() / 'minhas_notas'

# %%
pasta.mkdir(exist_ok=True)

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'minhas_notas', 'notas.txt', 'os.ipynb']

# %%
import shutil

shutil.move(nome_arquivo, pasta / nome_arquivo)
# Out:
# WindowsPath('c:/Users/8761221/Documents/Asimov/Python_Intermediario/explorando_a_biblioteca_padrao/minhas_notas/notas.txt')

# %%
os.listdir('minhas_Notas')
# Out:
# ['notas.txt']
