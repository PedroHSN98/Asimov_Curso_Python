# %% [markdown]
# ### Manipulação e busca em textos

# %%
import locale

# %%
locale.setlocale(locale.LC_ALL, '')
# Out:
# 'Portuguese_Brazil.1252'

# %%
x = 12.5

locale.str(x)
# Out:
# '12,5'

# %%
str(x)
# Out:
# '12.5'

# %%
y = 1279.95402
locale.currency(y, grouping=True)
# Out:
# 'R$ 1.279,95'

# %%
import re

# %%
texto = """
Nome: Marcos | Idade: 30| CPF: 012.345.678-90 | País de origem: Brasil
Nome: Ana |   Idade: 28 |CPF: 098.765.432-10    | País de origem: Brasil
Nome: Isadora   | Idade: Não informado | CPF:090.080.070-65 | País de origem: Brasil
Nome: Guilherme| Idade: 21 | CPF: 111.222.333-45| País de origem: Brasil
"""

# %%
padrao = r'\d{3}\.\d{3}\.\d{3}-\d{2}'
cpfs = re.findall(padrao, texto)
print(cpfs)
# Out:
# ['8']

# %%
padrao = r'[0-9]'

texto = 'Escrevi esse texto ha 8 anos atras'

# %%
match = re.search(padrao, texto)

# %%
match.group()
# Out:
# '8'

# %%
match.start(), match.end()
# Out:
# (22, 23)

# %%
texto[22:23]
# Out:
# '8'

# %%
padrao = r'[0-9]'

texto = 'Escrevi esse texto ha 8 anos atras'

# %%
valor = re.search(padrao, texto)

# %%
print(valor)
# Out:
# <re.Match object; span=(22, 23), match='8'>
