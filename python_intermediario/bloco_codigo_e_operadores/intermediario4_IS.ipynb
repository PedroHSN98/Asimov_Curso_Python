# %% [markdown]
# ## Identidade e o operador IS

# %%
#As Listas abaixo são iguais?
lista_a = [1, 2, 3, 4, 5]
lista_b = [1, 2, 3, 4, 5]

# %%
lista_a == lista_b
# Out:
# True

# %%
lista_a.append(6)
lista_a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
lista_a == lista_b
# Out:
# False

# %%
lista_a is lista_b
# Out:
# False

# %%
bolo_1 = {
    'sabor': 'chocolate',
    'tamanho': 'grande',
    'preço': 50,
}

bolo_2 = {
    'sabor': 'chocolate',
    'tamanho': 'grande',
    'preço': 50,
}

# %%
bolo_1 is bolo_2
# Out:
# False

# %%
bolo_1['preço'] = 80

# %%
valor = None

if valor is None:
    print('Valor é None')
else:
    print('Valor não é Nulo')
# Out:
# Valor é None
