# %% [markdown]
# # O Operador Morsa :=

# %%
valor_de_busca = 'xxx'

resultado = buscar_no_banco_de_dados(valor_de_busca)
if resultado is None:
    print(f'Nada foi encontrado para o valor de busca {valor_de_busca}.')
else:
    print(f'Resultado encontrado para valor de busca {valor_de_busca}: {resultado}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 valor_de_busca = 'xxx'
# ----> 3 resultado = buscar_no_banco_de_dados(valor_de_busca)
#       4 if resultado is None:
#       5     print(f'Nada foi encontrado para o valor de busca {valor_de_busca}.')
#
# NameError: name 'buscar_no_banco_de_dados' is not defined

# %%
valor_de_busca = 'xxx'

resultado := buscar_no_banco_de_dados(valor_de_busca) is None
if resultado is None:
    print(f'Nada foi encontrado para o valor de busca {valor_de_busca}.')
else:
    print(f'Resultado encontrado para valor de busca {valor_de_busca}: {resultado}')

# %%
n =  5
while n > 0:
    n -= 1
    print(n)
# Out:
# 4
# 3
# 2
# 1
# 0

# %%
n = 5 
while (n := n - 1) >= 0:
    print(n)
# Out:
# 4
# 3
# 2
# 1
